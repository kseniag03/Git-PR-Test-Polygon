# %% [markdown]
# # Задание 1
# Реализуйте функцию sum_distance(from, to_num), которая суммирует все числа от
# значения from до величины to_num включительно.
# Примечание. Если пользователь задаст первое число, которое окажется
# больше второго, просто поменяйте их местами.

# %%
def sum_distance(from_num, to_num):
  if from_num > to_num:
    from_num, to_num = to_num, from_num

  return sum(range(from_num, to_num + 1))

# %%
print(sum_distance(1, 5))
# Out:
# 15

# %%
print(sum_distance(1, 1000))
# Out:
# 500500

# %% [markdown]
# # Задание 2.
# Реализуйте функцию trim_and_repeat(), которая принимает три параметра:
#
# * строку;
# * offset — число символов, на которое нужно обрезать строку слева;
# * repetitions — сколько раз нужно повторить строку перед возвратом получившейся строки.
#
# Число символов для среза по умолчанию равно 0, а количество повторений — 1.
#
# Функция должна возвращать полученную строку.

# %%
def trim_and_repeat(text, offset = 0, repetitions = 1):
  return text[offset:] * repetitions

# %%
print(trim_and_repeat('хихихахахехехохо', 2, 5))
# Out:
# хихахахехехохохихахахехехохохихахахехехохохихахахехехохохихахахехехохо

# %%
print(trim_and_repeat('AAAAaaAAAaaAAaAaAA'))
# Out:
# AAAAaaAAAaaAAaAaAA

# %% [markdown]
# # Чек-лист самопроверки
#
# ☑ Установлен jupyter notebook либо используется google colab
#
# ☑ Создан профиль на https://github.com (<b>при использовании
# jupyter notebook</b>)
#
# ☑ Задание 1.
# Функция sum_distance(from, to) суммирует все числа от
# значения from до величины to включительно
#
# ☑ Задание 2.
# Функция trim_and_repeat() принимает три параметра (строку,
# offset, repetitions) и возвращает полученную строку
